# %% [markdown]
# **PROYECTO: SERVICIO AUTOMOTRIZ “AUTO MOTORS”**
#
# Empresa colombiana con franquicias. Ofrece servicios y productos como cambio de aceite, cambio de filtros, venta de cubiertas, llantas, entre otras.

# %% [markdown]
# **Descripción del proyecto**:
# Contamos con datos internos de la empresa como ventas y empleados.
# Requieren analizar el impacto de la pandemia para evaluar si vender la empresa, si
# quiebra o si salir a buscar inversores para expansión hacia otros países.
#
# **Objetivo**:
# El cliente necesita contar con toda la información ya analizada para tomar una decisión
# final.
#
# **Indicadores básicos para empezar**:
# Venta Total
# Cantidad de Elementos vendidos
# Ganancia Facturación Total de Servicios
# Cantidad de Servicios Ofrecidos
# Cantidad de Sedes o ubicaciones disponibles
# Ventas totales por Sedes en cada Rubro o Familia y Servicios
# Ventas realizadas por sus empleados
# Ranking de Ventas / Servicios de Empleados

# %%
import pandas as pd

# %%
empleados = pd.read_csv("/content/Empleados.csv",sep=";")

# %%
ventas = pd.read_csv("/content/Ventas1.csv",sep=";")
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (0,1,2,4,5,7,8,9,10,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
empleados
# Out:
#     Id_Empleado   Nombre y Apellido
# 0             1        Juan Pastran
# 1             2      Esteban Damico
# 2             3      Julian Quevedo
# 3             4       Oscar Rosseto
# 4             5   Valentin Quintero
# ..          ...                 ...
# 63           64    Eduardo Monardez
# 64           65      Leonardo Perez
# 65           66  Rodolfo Colmenares
# 66           67        Esteban Vera
# 67           68        Adrian Ortiz
#
# [68 rows x 2 columns]

# %%
ventas
# Out:
#            IdCliente             NombreCliente     Fecha  Empleado  \
# 0        C1070956433                PINTO JOHN  1/9/2016      24.0
# 1        C1032372566                CESAR CRUZ  1/9/2016      14.0
# 2           C2865810              PINEDA JAIME  1/9/2016      12.0
# 3          C11210285  VILLALBA RODRIGUEZ FABIO  1/9/2016      24.0
# 4          C80755314             MOLINA RONALD  1/9/2016      14.0
# ...              ...                       ...       ...       ...
# 1048570          NaN                       NaN       NaN       NaN
# 1048571          NaN                       NaN       NaN       NaN
# 1048572          NaN                       NaN       NaN       NaN
# 1048573          NaN                       NaN       NaN       NaN
# 1048574          NaN                       NaN       NaN       NaN
#
#           Referencia             Descripcion  CodigoFamilia Familia Cantidad  \
# 0         LL-2R-0038  PILOT STREET 110/80-17          101.0  LLANTA        1
# 1        LL-TCA-0133       TOURING 175/70R13          101.0  LLANTA        2
# 2        LL-TCA-0019    ENERGY XM2 185/65R14          101.0  LLANTA        1
# 3        LL-TCA-0009    ENERGY XM2 165/65R13          101.0  LLANTA        2
# 4        LL-TCA-0132             NO UTILIZAR          101.0  LLANTA        4
# ...              ...                     ...            ...     ...      ...
# 1048570          NaN                     NaN            NaN     NaN      NaN
# 1048571          NaN                     NaN            NaN     NaN      NaN
# 1048572          NaN                     NaN            NaN     NaN      NaN
# 1048573          NaN                     NaN            NaN     NaN      NaN
# 1048574          NaN                     NaN            NaN     NaN      NaN
#
#          Ventas      Localidad       Sede  Area
# 0        129310  Puente aranda   Calle 13  35.0
# 1        181034           Suba       Suba  32.0
# 2        193095        Usaquen  Santa ana  33.0
# 3        262069  Puente aranda   Calle 13  35.0
# 4        362069           Suba       Suba  32.0
# ...         ...            ...        ...   ...
# 1048570     NaN            NaN        NaN   NaN
# 1048571     NaN            NaN        NaN   NaN
# 1048572     NaN            NaN        NaN   NaN
# 1048573     NaN            NaN        NaN   NaN
# 1048574     NaN            NaN        NaN   NaN
#
# [1048575 rows x 13 columns]

# %%
df_empleados = pd.DataFrame(empleados)

# %%
df_empleados
# Out:
#     Id_Empleado   Nombre y Apellido
# 0             1        Juan Pastran
# 1             2      Esteban Damico
# 2             3      Julian Quevedo
# 3             4       Oscar Rosseto
# 4             5   Valentin Quintero
# ..          ...                 ...
# 63           64    Eduardo Monardez
# 64           65      Leonardo Perez
# 65           66  Rodolfo Colmenares
# 66           67        Esteban Vera
# 67           68        Adrian Ortiz
#
# [68 rows x 2 columns]

# %%
df_ventas = pd.DataFrame(ventas)

# %%
df_ventas
# Out:
#            IdCliente             NombreCliente     Fecha  Empleado  \
# 0        C1070956433                PINTO JOHN  1/9/2016      24.0
# 1        C1032372566                CESAR CRUZ  1/9/2016      14.0
# 2           C2865810              PINEDA JAIME  1/9/2016      12.0
# 3          C11210285  VILLALBA RODRIGUEZ FABIO  1/9/2016      24.0
# 4          C80755314             MOLINA RONALD  1/9/2016      14.0
# ...              ...                       ...       ...       ...
# 1048570          NaN                       NaN       NaN       NaN
# 1048571          NaN                       NaN       NaN       NaN
# 1048572          NaN                       NaN       NaN       NaN
# 1048573          NaN                       NaN       NaN       NaN
# 1048574          NaN                       NaN       NaN       NaN
#
#           Referencia             Descripcion  CodigoFamilia Familia Cantidad  \
# 0         LL-2R-0038  PILOT STREET 110/80-17          101.0  LLANTA        1
# 1        LL-TCA-0133       TOURING 175/70R13          101.0  LLANTA        2
# 2        LL-TCA-0019    ENERGY XM2 185/65R14          101.0  LLANTA        1
# 3        LL-TCA-0009    ENERGY XM2 165/65R13          101.0  LLANTA        2
# 4        LL-TCA-0132             NO UTILIZAR          101.0  LLANTA        4
# ...              ...                     ...            ...     ...      ...
# 1048570          NaN                     NaN            NaN     NaN      NaN
# 1048571          NaN                     NaN            NaN     NaN      NaN
# 1048572          NaN                     NaN            NaN     NaN      NaN
# 1048573          NaN                     NaN            NaN     NaN      NaN
# 1048574          NaN                     NaN            NaN     NaN      NaN
#
#          Ventas      Localidad       Sede  Area
# 0        129310  Puente aranda   Calle 13  35.0
# 1        181034           Suba       Suba  32.0
# 2        193095        Usaquen  Santa ana  33.0
# 3        262069  Puente aranda   Calle 13  35.0
# 4        362069           Suba       Suba  32.0
# ...         ...            ...        ...   ...
# 1048570     NaN            NaN        NaN   NaN
# 1048571     NaN            NaN        NaN   NaN
# 1048572     NaN            NaN        NaN   NaN
# 1048573     NaN            NaN        NaN   NaN
# 1048574     NaN            NaN        NaN   NaN
#
# [1048575 rows x 13 columns]

# %%
df_ventas = df_ventas.dropna()

# %%
df_ventas
# Out:
#           IdCliente                                      NombreCliente  \
# 0       C1070956433                                         PINTO JOHN
# 1       C1032372566                                         CESAR CRUZ
# 2          C2865810                                       PINEDA JAIME
# 3         C11210285                           VILLALBA RODRIGUEZ FABIO
# 4         C80755314                                      MOLINA RONALD
# ...             ...                                                ...
# 127250   C891100881                     MORENO VARGAS SOCIEDAD ANONIMA
# 127251   C900364615                              ORGANIZACION SUMA SAS
# 127252   C900365651  EMPRESA DE TRANSPORTE INTEGRADO DE BOGOTA ETIB...
# 127253   C900365651  EMPRESA DE TRANSPORTE INTEGRADO DE BOGOTA ETIB...
# 127254   C900364615                              ORGANIZACION SUMA SAS
#
#             Fecha  Empleado   Referencia             Descripcion  \
# 0        1/9/2016      24.0   LL-2R-0038  PILOT STREET 110/80-17
# 1        1/9/2016      14.0  LL-TCA-0133       TOURING 175/70R13
# 2        1/9/2016      12.0  LL-TCA-0019    ENERGY XM2 185/65R14
# 3        1/9/2016      24.0  LL-TCA-0009    ENERGY XM2 165/65R13
# 4        1/9/2016      14.0  LL-TCA-0132             NO UTILIZAR
# ...           ...       ...          ...                     ...
# 127250  10/3/2020       2.0  LL-PLC-0159  X WORKS HD XDY 12R22.5
# 127251  10/3/2020       1.0  LL-PLB-0024   X MULTI Z 235/75R17.5
# 127252  10/3/2020       2.0  LL-PLB-0024   X MULTI Z 235/75R17.5
# 127253  10/3/2020       2.0  LL-PLB-0031       XZE2 215/75 R17.5
# 127254  10/3/2020       1.0  LL-PLC-0074   X MULTI Z 295/80R22.5
#
#         CodigoFamilia Familia Cantidad    Ventas      Localidad  \
# 0               101.0  LLANTA        1    129310  Puente aranda
# 1               101.0  LLANTA        2    181034           Suba
# 2               101.0  LLANTA        1    193095        Usaquen
# 3               101.0  LLANTA        2    262069  Puente aranda
# 4               101.0  LLANTA        4    362069           Suba
# ...               ...     ...      ...       ...            ...
# 127250          101.0  LLANTA        4   5635766       Engativa
# 127251          101.0  LLANTA        9   6894000       Engativa
# 127252          101.0  LLANTA       20  11955636       Engativa
# 127253          101.0  LLANTA       30  15908063       Engativa
# 127254          101.0  LLANTA       14  21868000       Engativa
#
#                    Sede  Area
# 0              Calle 13  35.0
# 1                  Suba  32.0
# 2             Santa ana  33.0
# 3              Calle 13  35.0
# 4                  Suba  32.0
# ...                 ...   ...
# 127250  Ventas externas  22.0
# 127251  Ventas externas  22.0
# 127252  Ventas externas  22.0
# 127253  Ventas externas  22.0
# 127254  Ventas externas  22.0
#
# [127255 rows x 13 columns]

# %%
df_ventas['Sede'].unique()
# Out:
# array(['Calle 13', 'Suba', 'Santa ana', 'Ventas externas', 'Calle 80',
#        'Av Chile', 'Grandes flotas'], dtype=object)

# %%
df_ventas['Familia'].value_counts()
# Out:
# SERVICIOS      88230
# LLANTA         19426
# FILTROS        10291
# LUBRICANTES     4832
# REENCAUCHE      4476
# Name: Familia, dtype: int64

# %%
df_ventas['Empleado'].value_counts()
# Out:
# 10.0    22400
# 14.0    16357
# 2.0     13719
# 44.0    10261
# 36.0     8247
# 45.0     6847
# 50.0     6327
# 56.0     5518
# 29.0     4624
# 3.0      4445
# 55.0     3833
# 24.0     3436
# 12.0     3216
# 48.0     2916
# 6.0      1839
# 15.0     1330
# 22.0     1161
# 27.0     1160
# 13.0     1054
# 38.0     1019
# 41.0      990
# 1.0       976
# 51.0      788
# 63.0      711
# 33.0      558
# 7.0       527
# 37.0      501
# 4.0       434
# 39.0      212
# 28.0      187
# 64.0      171
# 43.0      165
# 20.0      159
# 35.0      157
# 66.0      136
# 57.0      114
# 47.0      111
# 54.0      104
# 67.0       90
# 30.0       78
# 62.0       59
# 32.0       57
# 5.0        50
# 61.0       42
# 65.0       30
# 52.0       28
# 31.0       23
# 21.0       19
# 46.0       17
# 11.0       14
# 16.0       12
# 8.0        10
# 40.0        8
# 68.0        4
# 42.0        3
# 9.0         1
# Name: Empleado, dtype: int64

# %% [markdown]
# **Indicadores básicos**

# %% [markdown]
# Venta Total = 74426081596

# %% [markdown]
# Cantidad de Elementos vendidos = 315067,074

# %% [markdown]
# Ganancia Facturación Total de Servicios = 74330622939

# %% [markdown]
# Cantidad de Servicios Ofrecidos = 88230

# %% [markdown]
# Cantidad de Sedes o ubicaciones disponibles = 'Calle 13', 'Suba', 'Santa ana', 'Ventas externas', 'Calle 80',
#        'Av Chile', 'Grandes flotas'

# %% [markdown]
# Ventas totales por Sedes en cada Rubro o Familia y Servicios

# %% [markdown]
# Ranking de Ventas / Servicios de Empleados =
#
# 1)Adrián Lucero
# 2)Javier Garay
# 3)Esteban Damico
# 4)Juan Casivar
# 5)Luis Barquiel
# 6)Nicolas Castro

# %% [markdown]
# Ventas realizadas por sus empleados =
#
# 1)22400
# 2)16357
# 3)13719
# 4)10261
# 5)8247
# 6)6847

# %% [markdown]
# ![Captura1.PNG](data:image/png;base64,...)

# %% [markdown]
# ![Captura2.PNG](data:image/png;base64,...)

# %% [markdown]
# ![Captura3.PNG](data:image/png;base64,...)
